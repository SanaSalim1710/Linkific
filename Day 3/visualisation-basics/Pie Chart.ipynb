# %%
import matplotlib.pyplot as plt

plt.title("Favourite Animals")
animals = ["Giraffe", "Lion", "Tiger", "Zebra", "Hippo"]
data = [15, 45, 25, 10, 5]
plt.pie(data, labels=animals, autopct="%1.1f%%")
plt.show()
