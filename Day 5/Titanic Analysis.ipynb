# %% [markdown]
# # Analyse Titanic Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/sanasalim/Downloads/Day 4/Titanic-Dataset.csv")

# %% [markdown]
# ### Are most of the survivors men or women?

# %%
survived_sex = df.groupby("Sex")["Survived"].sum()
print(survived_sex)
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
ax2 = survived_sex.round(1).plot(kind="bar",title="Survivors")
ax2.set_ylabel("No. of Survivors")
for container in ax2.containers:
    ax2.bar_label(container)

# %%
sex_survival_rate = df.groupby("Sex")["Survived"].mean()*100
print(sex_survival_rate)
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
df.groupby("Sex")["PassengerId"].count()
# Out:
# Sex
# female    314
# male      577
# Name: PassengerId, dtype: int64

# %% [markdown]
# Percentage of women who survived vs percentage of men who survived

# %%
ax = sex_survival_rate.round(1).plot(kind="bar",title="Survival Rate by Sex")
ax.set_ylabel("Survival Rate (%)")
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### Average age by passenger class

# %%
avg_age_class = df.groupby("Pclass")["Age"].mean()
print(avg_age_class)
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
ax1 = avg_age_class.round(1).plot.barh()
ax1.set_xlabel("Average Age")
ax1.set_ylabel("Passenger Class")
for container in ax1.containers:
    ax1.bar_label(container)

# %% [markdown]
# ### Survival rate by embarkation port

# %%
port_survival = df.groupby("Embarked")["Survived"].sum()
port_survival_rate = df.groupby("Embarked")["Survived"].mean().round(4)*100
survived_port = df.groupby("Embarked").size()
print(survived_port)
print(port_survival)
print("\nPort Survival Rate:\n",port_survival_rate)
print(len(df))
# Out:
# Embarked
# C    168
# Q     77
# S    644
# dtype: int64
# Embarked
# C     93
# Q     30
# S    217
# Name: Survived, dtype: int64
#
# Port Survival Rate:
#  Embarked
# C    55.36
# Q    38.96
# S    33.70
# Name: Survived, dtype: float64
# 891

# %%
ax3 = port_survival_rate.round(1).plot.barh()
ax3.set_xlabel("Survival Rate (%)")
ax3.set_ylabel("Embarkation Port")
for container in ax3.containers:
    ax3.bar_label(container)

# %% [markdown]
# ### Age Distribution

# %%
df["Age"].hist(grid=False)
# Out:
# <Axes: >
